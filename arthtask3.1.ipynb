# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img1=cv2.imread('img1.jpeg')

# %%
plt.imshow(img1)

# %%
print(img1.shape)
# Out:
# (1481, 1266, 3)

# %%
img2=cv2.imread('img2.jpeg')

# %%
plt.imshow(img2)

# %%
img2=cv2.resize(img2,(1266,1481))

# %%
print(img1.shape)
# Out:
# (1481, 1266, 3)

# %%
print(img2.shape)
# Out:
# (1481, 1266, 3)

# %%
merge=np.hstack((img1,img2))

# %%
plt.imshow(merge)
